# %%
from astropy.io import fits
from pathlib import Path
import numpy as np
import sys
import numpy
from matplotlib.pyplot import figure, show, subplots
import numpy.ma as ma


datadir = "/net/virgo01/data/users/oassenberg/ObsAs/i"  #my data folder
 
#this sets the path that the program has to follow to get to our data!
path = Path(datadir)
filepaths_ = []
for filepath in path.iterdir():
    filepaths_.append(filepath)

filepaths = np.array(filepaths_)

filepaths.sort()
print(filepaths[0])
print(filepaths[-2])

#285 - 295 -> Biases 

#363 and 637 and 609 are missing!
BIAS = []

for i in range(0, 11):
    BIAS.append(filepaths[i])
for i in range(798-288, 809-288):
    BIAS.append(filepaths[i])


DARK = []

for i in range(11, 18):
    DARK.append(filepaths[i])
for i in range(783-288, 798-288):
    DARK.append(filepaths[i])

FLATB = []

for i in range(303-285, 308-285):
    FLATB.append(filepaths[i])
for i in range(812-288, 815-288):
    FLATB.append(filepaths[i])

FLATV = []

for i in range(308-285, 313-285):
    FLATV.append(filepaths[i])
for i in range(815-288, 818-288):
    FLATV.append(filepaths[i])

FLATR = []

for i in range(314-285, 320-285):
    FLATR.append(filepaths[i])
for i in range(809-288, 812-288):
    FLATR.append(filepaths[i])

LIGHTR = []
LIGHTV = []
LIGHTB = []


for i in range(363-285, 604-286, 3):
    LIGHTR.append(filepaths[i])
for i in range(365-286, 604-286, 3):
    LIGHTV.append(filepaths[i])
for i in range(366-286, 604-286, 3):
    LIGHTB.append(filepaths[i])

for i in range(616-287, 636-287, 3):
    LIGHTR.append(filepaths[i])
for i in range(617-287, 636-287, 3):
    LIGHTV.append(filepaths[i])
for i in range(618-287, 636-287, 3):
    LIGHTB.append(filepaths[i])
    
for i in range(638-288, 758-288, 3):
    LIGHTR.append(filepaths[i])
for i in range(639-288, 758-288, 3):
    LIGHTV.append(filepaths[i])
for i in range(640-288, 758-288, 3):
    LIGHTB.append(filepaths[i])

GD336 = []
for i in range(759-288, 774-288):
    GD336.append(filepaths[i])
# Out:
# /net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000285.Mouse_click_position.BIAS.FIT
# /net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000817.17h03m03.8s_69d55m49sN.FLAT.FIT
# [PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000366.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000369.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000372.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000375.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000378.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000381.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000384.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000387.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000390.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000393.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000396.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000399.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000402.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000405.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000408.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000411.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000414.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000417.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000420.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000423.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000426.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000429.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000432.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000435.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000438.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000441.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000444.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000447.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000450.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000453.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000456.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000459.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000462.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000465.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000468.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000471.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oassenberg/ObsAs/i/260430_LI_.00000474.Mouse_click_position.BLUE.FIT'), PosixPath('/net/virgo01/data/users/oasse ...
