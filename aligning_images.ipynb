# %%
import astroalign as a

LIGHTV_aligned = [LIGHTV_reduced[0]] # adding the target image to the list manually cause i dont think it will get appended in the for loop
LIGHTB_aligned = [LIGHTB_reduced[0]]

BV = []
BV_aligned = []

for i in range(len(LIGHTV_reduced)):
    registered_image_V, footprint = aa.register(LIGHTV_reduced[i], LIGHTV_reduced[0])
    LIGHTV_aligned.append(registered_image_V)

for i in range(len(LIGHTB_reduced)):
    registered_image_B, footprint = aa.register(LIGHTB_reduced[i], LIGHTB_reduced[0])
    LIGHTB_aligned.append(registered_image_B)
